# %% [markdown]
# # Generate Multiple Choice Questions from a Text

# %% [markdown]
# ## PROBLEM STATEMENT
# Given a text phrase, we want to generate multiple choice questions (MCQ)s automatically from the text. The tool can be used by educators, teachers or by professionals to create assesments, evaluations, quizes surveys at scale.

# %% [markdown]
# ## Introduction
#
# MCQs have several advantages, including rapid evaluation, shorter testing time, uniform scoring, and the option of an electronic evaluation. Many examinations employ MCQ-based question papers administered in a computerised setting. Manually preparing MCQs, on the other hand, is time-consuming and costly. As a result, the research community expended much effort in developing approaches for the automatic creation of MCQs. We will explore one such method here using machine learning and natural language processing.

# %%
# We will use following text as an example
# source: https://www.fresherslive.com/online-test/reading-comprehension-test-questions-and-answers
text = """The Dust Bowl, considered one of the greatest man-made ecological disasters, was a period of severe dust storms that lasted nearly a decade, starting 1931, and engulfed large parts of the US. The dust storms originated in the Great Plains-from states like Texas, Oklahoma, New Mexico, Colorado and Kansas. They were so severe that they choked everything and blocked out the sun for days. Sometimes, the storms travelled thousands of kilometres and blotted out monuments such as the Statue of Liberty. Citizens developed “dust pneumonia” and experienced chest pain and difficulty in breathing. The storms damaged the soil in around 100 million acres of land, leading to the greatest short-time migration in the American history, with approximately 3.5 million people abandoning their farms and fields.

Dust storms are an annual weather pattern in the northern region of India comprising Delhi, Haryana, Punjab, Uttar Pradesh and Rajasthan and Punjab, as also in the Sindh region of Pakistan. But, they are normally low in intensity and accompanied by rains. In fact, people welcome dust storms as they bring down temperatures and herald the arrival of the monsoons. But, the dust storms that have hit India since February this year have been quantitatively and qualitatively different from those in the past. They are high-powered storms travelling long distances and destroying properties and agricultural fields. Since February, they have affected as many as 16 states and killed more than 500 people. Cities like Delhi were choked in dust for days, with air quality level reaching the “severe” category on most days.

The Dust Bowl areas of the Great Plains are largely arid and semi-arid and prone to extended periods of drought. The US federal government encouraged settlement and development of large-scale agriculture by giving large parcels of grasslands to settlers. Waves of European settlers arrived at the beginning of the 20th century and converted grasslands into agricultural fields. At the same time, technological improvements allowed rapid mechanization of farm equipment, especially tractors and combined harvesters, which made it possible to operate larger parcels of land.

For the next two decades, agricultural land grew manifold and farmers undertook extensive deep ploughing of the topsoil with the help of tractors to plant crops like wheat. This displaced the native, deep-rooted grasses that trapped soil and moisture even during dry periods and high winds. Then, the drought struck. Successive waves of drought, which started in 1930 and ended in 1939, turned the Great Plains into bone-dry land. As the soil was already loose due to extensive ploughing, high winds turned them to dust and blew them away in huge clouds. Does this sound familiar? The dust storm regions of India and Pakistan too are largely arid and semi-arid. But they are at a lower altitude and hence less windy compared to the Great Plains. Over the last 50 years, chemical- and water-intensive agriculture has replaced the traditional low-input agriculture. Canal irrigation has been overtaken by the groundwater irrigation. In addition, mechanized agriculture has led to deeper ploughing, loosening more and more topsoil. The result has been devastating for the soil and groundwater. In most of these areas, the soil has been depleted and groundwater levels have fallen precipitously. On top of the man-made ecological destruction, the natural climatic cycle along with climate change is affecting the weather pattern of this region.

First, this area too is prone to prolonged drought. In fact, large parts of Haryana, Punjab, Delhi and western UP have experienced mildly dry to extremely dry conditions in the last six years. The Standardized Precipitation Index (SPI), which specifies the level of dryness or excess rains in an area, of large parts of Haryana, Punjab and Delhi has been negative since 2012. Rajasthan, on the other hand shows a positive SPI or excess rainfall. Second, this area is experiencing increasing temperatures. In fact, there seems to be a strong correlation between the dust storms and the rapid increase in temperature. Maximum temperatures across northern and western India have been far higher than normal since April this year. Last, climate change is affecting the pattern of Western Disturbances (WDs), leading to stronger winds and stronger storms. WDs are storms originating in the Mediterranean region that bring winter rain to northwestern India. But because of the warming of the Arctic and the Tibetan Plateau, indications are that the WDs are becoming unseasonal, frequent and stronger.

The Dust Bowl led the US government to initiate a large-scale land-management and soil-conservation programme. Large-scale shelterbelt plantations, contour ploughing, conservation agriculture and establishment of conservation areas to keep millions of acres as grassland, helped halt wind erosion and dust storms. It is time India too recognizes its own Dust Bowl and initiates a large-scale ecological restoration programme to halt it. Else, we will see more intense dust storms, and a choked Delhi would be a permanent feature.
"""

# %%
len(text)
# Out:
# 5163

# %% [markdown]
# ## Sentence Selection and Question Generation
# In order to generate questions we must first identify significant sentences that hold fact or knowledge. There two broad ways to do this:
#
# ### a. Name Entity Recognition:
# We can identify important names, locations and formulate them as questions.
# If we want to test grammar skills we can idenity instead verbs, nouns and   other adpositions.
#
# ### b. Keyword Extraction:
# We identify important keywords from our text, and then formulate questions such that those keywords as answers. We will explore this method in this notebook.
#
# ### Question Generation:
# For generating question,  we have two broad ways:<br>
# a. Either we can train a model that takes answer and context as input, and generates a question. This would be a sequence to sequence problem. This is opposite of Question Answering task where we feed the model and Question, and context and it generates a answer. We can use the same dataset instead to formulate questions.  The advantage of this method is we can proper questions.
#
# b. Another simple way we can formulate questions, is  just by replacing the keyword in the original text with a blank. This would generate only fill in the blanks type declarative questions. It will be very straightforward and easy to implement. The advantage is it's easy to implement and we don't need any machine learning model.
#
# We explore both ways in this notebook, but we preferred the second method in production.

# %% [markdown]
# ## Identifying Keywords

# %%
# !pip install keybert > /dev/null
from sentence_transformers import SentenceTransformer
from keybert import KeyBERT
from nltk.tokenize import sent_tokenize
import nltk

# we use nltk library to tokenize our text
nltk.download('punkt')

# KeyBert uses BERT-embeddings and simple cosine similarity to find the sub-phrases in a document that are the most similar to the document itself.
sentence_model = SentenceTransformer("all-MiniLM-L6-v2")
kw_model = KeyBERT(sentence_model)

def get_keywords(text):
    """
    Given @input text, identify important keywords. 
    Here we use Sentence Transformer to extract keywords that best describe the text
    """
    keywords_with_scores = kw_model.extract_keywords(text, keyphrase_ngram_range=(1, 2), top_n=5, stop_words='english')
    keywords = [kw[0] for kw in keywords_with_scores]
    scores = [kw[1] for kw in keywords_with_scores]
    return keywords

def tokenize_sentences(text):
    """
    Given a @text input, returns tokenized sentences
    """
    sentences = [sent_tokenize(text)]
    sentences = [sentence for paragraph in sentences for sentence in paragraph]

    # Remove sentences shorter than 20 letters.
    sentences = [sentence.strip() for sentence in sentences if len(sentence) > 20]
    return sentences

def get_sentences_for_keyword(kw_model, sentences, lemmatizer):
    """
    @kw_model: keyBERT model to extract keywords
    @sentences: list of tokenized sentences
    returns a map with keywords as keys mapped to the sentences they appear in.
    """
    keyword_sentences = {}
    for sentence in sentences:
        keywords_found = [kw[0] for kw in kw_model.extract_keywords(sentence, keyphrase_ngram_range=(1, 2), top_n=10) if len(kw[0]) > 2]
        for key in keywords_found:
            keyword_sentences[key] = keyword_sentences.get(key, [])
            keyword_sentences[key].append(sentence)

    return keyword_sentences
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2022-01-15 16:54:47.682 Load pretrained SentenceTransformer: all-MiniLM-L6-v2
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 2022-01-15 16:54:51.989 Use pytorch device: cpu

# %%
# Tokenize text into sentences
sentences = tokenize_sentences(text)

# find important keywords along with sentences they appear in
keyword_to_sentences_map = get_sentences_for_keyword(kw_model, sentences)

for word in keyword_to_sentences_map:
    print (word, " : ",keyword_to_sentences_map[word],"\n")
# Out:
# dust  :  ['The Dust Bowl, considered one of the greatest man-made ecological disasters, was a period of severe dust storms that lasted nearly a decade, starting 1931, and engulfed large parts of the US.', 'Dust storms are an annual weather pattern in the northern region of India comprising Delhi, Haryana, Punjab, Uttar Pradesh and Rajasthan and Punjab, as also in the Sindh region of Pakistan.', 'But, the dust storms that have hit India since February this year have been quantitatively and qualitatively different from those in the past.', 'As the soil was already loose due to extensive ploughing, high winds turned them to dust and blew them away in huge clouds.', 'It is time India too recognizes its own Dust Bowl and initiates a large-scale ecological restoration programme to halt it.', 'Cities like Delhi were choked in dust for days, with air quality level reaching the “severe” category on most days.', 'The dust storms originated in the Great Plains-from states like Texas, Oklahoma, New Mexico, Colorado and Kansas.', 'The Dust Bowl areas of the Great Plains are largely arid and semi-arid and prone to extended periods of drought.', 'In fact, there seems to be a strong correlation between the dust storms and the rapid increase in temperature.', 'The Dust Bowl led the US government to initiate a large-scale land-management and soil-conservation programme.', 'In fact, people welcome dust storms as they bring down temperatures and herald the arrival of the monsoons.', 'Else, we will see more intense dust storms, and a choked Delhi would be a permanent feature.', 'Citizens developed “dust pneumonia” and experienced chest pain and difficulty in breathing.', 'The dust storm regions of India and Pakistan too are largely arid and semi-arid.']
#
# disasters  :  ['The Dust Bowl, considered one of the greatest man-made ecological disasters, was a period of severe dust storms that lasted nearly a decade, starting 1931, and engulfed large parts of the US.']
#
# storms  :  ['The storms damaged the soil in around 100 million acres of land, leading to the greatest short-time migration in the American history, with approximately 3.5 million people abandoning their farms and fields.', 'The Dust Bowl, considered one of the greatest man-made ecological disasters, was a period of severe dust storms that lasted nearly a decade, starting 1931, and engulfed large parts of the US.', 'Dust storms are an annual weather pattern in the northern region of India comprising Delhi, Haryana, Punjab, Uttar Pradesh and Rajasthan and Punjab, as also in the Sindh region of Pakistan.', 'But, the dust storms that have hit India since February this year have been quantitatively and qualitatively different from those in the past.', 'Last, climate change is affecting the pattern of Western Disturbances (WDs), leading to stronger winds and stronger storms.', 'The dust storms originated in the Great Plains-from states like Texas, Oklahoma, New Mexico, Colorado and Kansas.', 'Sometimes, the storms travelled thousands of kilometres and blotted out monuments such as the Statue of Liberty.', 'In fact, there seems to be a strong correlation between the dust storms and the rapid increase in temperature.', 'In fact, people welcome dust storms as they bring down temperatures and herald the arrival of the monsoons.', 'They are high-powered storms travelling long distances and destroying properties and agricultural fields.', 'WDs are storms originating in the Mediterranean region that bring winter rain to northwestern India.', 'Else, we will see more intense dust storms, and a choked Delhi would be a permanent feature.']
#
# bowl  :  ['The Dust Bowl, considered one of the greatest man-made ecological disasters, was a period of severe dust storms that lasted nearly a decade, starting 1931, and engulfed large parts of the US.', 'It is time India too recognizes its own Dust Bowl and initiates a large-scale ecological restoration programme to halt it.', 'The Dust Bowl areas of the Great Plains are largely arid and semi-arid and prone to extended periods of drought.', 'The Dust Bowl led the US government to initiate a large-scale land-management and soil-conservation programme.']
#
# 1931  :  ['The Dust Bowl, considered one of the greatest man-made ecological disasters, was a period of severe dust storms that lasted nearly a decade, starting 1931, and engulfed large parts of the US.']
#
# ecological  :  ['The Dust Bowl, considered one of the greatest man-made ecological disasters, was a period of severe dust storms that lasted nearly a decade, starting 1931, and engulfed large parts of the US.', 'On top of the man-made ecological destruction, the natural climatic cycle along with climate change is affecting the weather pattern of this region.', 'It is time India too recognizes its own Dust Bowl and initiates a large-scale ecological restoration programme to halt it.']
#
# decade  :  ['The Dust Bowl, considered one of the greatest man-made ecological disasters, was a period of severe dust storms that lasted nearly a decade, starting 1931, and engulfed large parts of the US.']
#
# engulfed  :  ['The Dust Bowl, considered one of the greatest man-made ecological disasters, was a period of severe dust storms that lasted nearly a decade, starting 1931, and engulfed large parts of the US.']
#
# greatest  :  ['The Dust Bowl, considered one of the greatest man-made ecological disasters, was a period of severe dust storms that lasted nearly a decade, starting 1931, and engulfed large parts of the US.']
#
# period  :  ['The Dust Bowl, considered one of the greatest man-made ecological disasters, was a period of severe dust storms that lasted nearly a decade, starting 1931, and engulfed large parts of the US.']
#
# plains  :  ['The dust storms originated in the Great Plains-from states like Texas, Oklahoma, New Mexico, Colorado and Kansas.', 'Successive waves of drought, which started in 1930 and ended in 1939, turned the Great Plains into bone-dry land.', 'The Dust Bowl areas of the Great Plains are largely arid and semi-arid and prone to extended periods of drought.', 'But they are at a lower altitude and hence less windy compared to the Great Plains.']
#
# originated  :  ['The dust storms originated in the Great Plains-from states like Texas, Oklahoma, New Mexico, Colorado and Kansas.']
#
# oklahoma  :  ['The dust storms originated in the Great Plains-from states like Texas, Oklahoma, New Mexico, Colorado and Kansas.']
#
# kansas  :  ['The dust storms originated in the Great Plains-from states like Texas, Oklahoma, New Mexico, Colorado and Kansas.']
#
# texas  :  ['The dust storms originated in the Great Plains-from states like Texas, Oklahoma, New Mexico, Colorado and Kansas.']
#
# colorado  :  ['The dust storms originated in the Great Plains-from states like Texas, Oklahoma, New Mexico, Colorado and Kansas.']
#
# states  :  ['The dust storms originated in the Great Plains-from states like Texas, Oklahoma, New Mexico, Colorado and Kansas.', 'Since February, they have affected as many as 16 states and killed more than 500 people.']
#
# mexico  :  ['The dust storms originated in the Great Plains-from states like Texas, Oklahoma, New Mexico, Colorado and Kansas.']
#
# choked  :  ['Cities like Delhi were choked in dust for days, with air quality level reaching the “severe” category on most days.', 'Else, we will see more intense dust storms, and a choked Delhi would be a permanent feature.', 'They were so severe that they choked everything and blocked out the sun for days.']
#
# sun  :  ['They were so severe that they choked everything and blocked out the sun for days.']
#
# severe  :  ['Cities like Delhi were choked in dust for days, with air quality level reaching the “severe” category on most days.', 'They were so severe that they choked everything and blocked out the sun for days.']
#
# days  :  ['Cities like Delhi were choked in dust for days, with air quality level reaching the “severe” category on most days.', 'They were so severe that they choked everything and blocked out the sun for days.']
#
# blocked  :  ['They were so severe that they choked everything and blocked out the sun for days.']
#
# monuments  :  ['Sometimes, the storms travelled thousands of kilometres and blotted out monuments such as the Statue of Liberty.']
#
# statue  :  ['Sometimes, the storms travelled thousands of kilometres and blotted out monuments such as the Statue of Liberty.']
#
# travelled  :  ['Sometimes, the storms travelled thousands of kilometres and blotted out monuments such as the Statue of Liberty.']
#
# kilometres  :  ['Sometimes, the storms travelled thousands of kilometres and blotted out monuments such as the Statue of Liberty.']
#
# liberty  :  ['Sometimes, the storms travelled thousands of kilometres and blotted out monuments such as the Statue of Liberty.']
#
# thousands  :  ['Sometimes, the storms travelled thousands of kilometres and blotted out monuments such as the Statue of Liberty.']
#
# blotted  :  ['Sometimes, the storms travelled thousands of kilometres and blotted out monuments such as the Statue of Liberty.']
#
# pneumonia  :  ['Citizens developed “dust pneumonia” and experienced chest pain and difficulty in breathing.']
#
# breathing  :  ['Citizens developed “dust pneumonia” and experienced chest pain and difficulty in breathing.']
#
# chest  :  ['Citizens developed “dust pneumonia” and experienced chest pain and difficulty in breathing.']
#
# citizens  :  ['Citizens developed “dust pneumonia” and experienced chest pain and difficulty in breathing.']
#
# pain  :  ['Citizens developed “dust pneumonia” and experienced chest pain and difficulty in breathing.']
#
# experienced  :  ['In fact, large parts of Haryana, Punjab, Delhi and western UP have experienced mildly dry to extremely dry conditions in the last six years.', 'Citizens developed “dust pneumonia” and experienced chest pain and difficulty in breathing.']
#
# difficulty  :  ['Citizens developed “dust pneumonia” and experienced chest pain and difficulty in breathing.']
#
# developed  :  ['Citizens developed “dust pneumonia” and experienced chest pain and difficulty in breathing.']
#
# soil  :  ['The storms damaged the soil in around 100 million acres of land, leading to the greatest short-time migration in the American history, with approximately 3.5 million people abandoning their farms and fields.', 'As the soil was already loose due to extensive ploughing, high winds turned them to dust and blew them away in huge clouds.', 'This displaced the native, deep-rooted grasses that trapped soil and moisture even during dry periods and high winds.', 'The Dust Bowl led the US government to initiate a large-scale land-management and soil-conservation programme.', 'In most of these areas, the soil has been depleted and groundwater levels have fallen precipitously.', 'The result has been devastating for the soil and groundwater.']
#
# acres  :  ['The storms damaged the soil in around 100 million acres of land, leading to the greatest short-time migration in the American history, with approximately 3.5 million people abandoning their farms and fields.', 'Large-scale shelterbelt plantations, contour ploughing, conservation agriculture and establishment of conservation areas to keep millions of acres as grassland, helped halt wind erosion and dust storms.']
#
# farms  :  ['The storms damaged the soil in around 100 million acres of land, leading to the greatest short-time migration in the American history, with approximately 3.5 million people abandoning their farms and fields.']
#
# land  :  ['The storms damaged the soil in around 100 million acres of land, leading to the greatest short-time migration in the American history, with approximately 3.5 million people abandoning their farms and fields.', 'At the same time, technological improvements allowed rapid mechanization of farm equipment, especially tractors and combined harvesters, which made it possible to operate larger parcels of land.', 'For the next two decades, agricultural land grew manifold and farmers undertook extensive deep ploughing of the topsoil with the help of tractors to plant crops like wheat.', 'Successive waves of drought, which started in 1930 and ended in 1939, turned the Great Plains into bone-dry land.', 'The Dust Bowl led the US government to initiate a large-scale land-management and soil-conservation programme.']
#
# migration  :  ['The storms damaged the soil in around 100 million acres of land, leading to the greatest short-time migration in the American history, with approximately 3.5 million people abandoning their farms and fields.']
#
# abandoning  :  ['The storms damaged the soil in around 100 million acres of land, leading to the greatest short-time migration in the American history, with approximately 3.5 million people abandoning their farms and fields.']
#
# million  :  ['The storms damaged the soil in around 100 million acres of land, leading to the greatest short-time migration in the American history, with approximately 3.5 million people abandoning their farms and fields.']
#
# damaged  :  ['The storms damaged the soil in around 100 million acres of land, leading to the greatest short-time migration in the American history, with approximately 3.5 million people abandoning their farms and fields.']
#
# history  :  ['The storms damaged the soil in around 100 million acres of land, leading to the greatest short-time migration in the American history, with approximately 3.5 million people abandoning their farms and fields.']
#
# punjab  :  ['Dust storms are an annual weather pattern in the northern region of India comprising Delhi, Haryana, Punjab, Uttar Pradesh and Rajasthan and Punjab, as also in the Sindh region of Pakistan.', 'The Standardized Precipitation Index (SPI), which specifies the level of dryness or excess rains in an area, of large parts of Haryana, Punjab and Delhi has been negative since 2012.', 'In fact, large parts of Haryana, Punjab, Delhi and western UP have experienced mildly dry to extremely dry conditions in the last six years.']
#
# haryana  :  ['Dust storms are an annual weather pattern in the northern region of India comprising Delhi, Haryana, Punjab, Uttar Pradesh and Rajasthan and Punjab, as also in the Sindh region of Pakistan.', 'The Standardized Precipitation Index (SPI), which specifies the level of dryness or excess rains in an area, of large parts of Haryana, Punjab and Delhi has been negative since 2012.', 'In fact, large parts of Haryana, Punjab, Delhi and western UP have experienced mildly dry to extremely dry conditions in the last six years.']
#
# rajasthan  :  ['Dust storms are an annual weather pattern in the northern region of India comprising Delhi, Haryana, Punjab, Uttar Pradesh and Rajasthan and Punjab, as also in the Sindh region of Pakistan.', 'Rajasthan, on the other hand shows a positive SPI or excess rainfall.']
#
# weather  :  ['Dust storms are an annual weather pattern in the northern region of India comprising Delhi, Haryana, Punjab, Uttar Pradesh and Rajasthan and Punjab, as also in the Sindh region of Pakistan.', 'On top of the man-made ecological destruction, the natural climatic cycle along with climate change is affecting the weather pattern of this region.']
#
# pradesh  :  ['Dust storms are an annual weather pattern in the northern region of India comprising Delhi, Haryana, Punjab, Uttar Pradesh and Rajasthan and Punjab, as also in the Sindh region of Pakistan.']
#
# india  :  ['Dust storms are an annual weather pattern in the northern region of India comprising Delhi, Haryana, Punjab, Uttar Pradesh and Rajasthan and Punjab, as also in the Sindh region of Pakistan.', 'But, the dust storms that have hit India since February this year have been quantitatively and qualitatively different from those in the past.', 'It is time India too recognizes its own Dust Bowl and initiates a large-scale ecological restoration programme to halt it.', 'Maximum temperatures across northern and western India have been far higher than normal since April this year.', 'WDs are storms originating in the Mediterranean region that bring winter rain to northwestern India.', 'The dust storm regions of India and Pakistan too are largely arid and semi-arid.']
#
# uttar  :  ['Dust storms are an annual weather pattern in the northern region of India comprising Delhi, Haryana, Punjab, Uttar Pradesh and Rajasthan and Punjab, as also in the Sindh region of Pakistan.']
#
# sindh  :  ['Dust storms are an annual weather pattern in the northern region of India comprising Delhi, Haryana, Punjab, Uttar Pradesh and Rajasthan and Punjab, as also in the Sindh region of Pakistan.']
#
# rains  :  ['The Standardized Precipitation Index (SPI), which specifies the level of dryness or excess rains in an area, of large parts of Haryana, Punjab and Delhi has been negative since 2012.', 'But, they are normally low in intensity and accompanied by rains.']
#
# intensity  :  ['But, they are normally low in intensity and accompanied by rains.']
#
# low  :  ['Over the last 50 years, chemical- and water-intensive agriculture has replaced the traditional low-input agriculture.', 'But, they are normally low in intensity and accompanied by rains.']
#
# normally  :  ['But, they are normally low in intensity and accompanied by rains.']
#
# accompanied  :  ['But, they are normally low in intensity and accompanied by rains.']
#
# monsoons  :  ['In fact, people welcome dust storms as they bring down temperatures and herald the arrival of the monsoons.']
#
# temperatures  :  ['Maximum temperatures across northern and western India have been far higher than normal since April this year.', 'In fact, people welcome dust storms as they bring down temperatures and herald the arrival of the monsoons.', 'Second, this area is experiencing increasing temperatures.']
#
# arrival  :  ['In fact, people welcome dust storms as they bring down temperatures and herald the arrival of the monsoons.']
#
# people  :  ['In fact, people welcome dust storms as they bring down temperatures and herald the arrival of the monsoons.', 'Since February, they have affected as many as 16 states and killed more than 500 people.']
#
# bring  :  ['In fact, people welcome dust storms as they bring down temperatures and herald the arrival of the monsoons.', 'WDs are storms originating in the Mediterranean region that bring winter rain to northwestern India.']
#
# welcome  :  ['In fact, people welcome dust storms as they bring down temperatures and herald the arrival of the monsoons.']
#
# herald  :  ['In fact, people welcome dust storms as they bring down temperatures and herald the arrival of the monsoons.']
#
# fact  :  ['In fact, large parts of Haryana, Punjab, Delhi and western UP have experienced mildly dry to extremely dry conditions in the last six years.', 'In fact, there seems to be a strong correlation between the dust storms and the rapid increase in temperature.', 'In fact, people welcome dust storms as they bring down temperatures and herald the arrival of the monsoons.']
#
# qualitatively  :  ['But, the dust storms that have hit India since February this year have been quantitatively and qualitatively different from those in the past.']
#
# quantitatively  :  ['But, the dust storms that have hit India since February this year have been quantitatively and qualitatively different from those in the past.']
#
# february  :  ['But, the dust storms that have hit India since February this year have been quantitatively and qualitatively different from those in the past.', 'Since February, they have affected as many as 16 states and killed more than 500 people.']
#
# year  :  ['But, the dust storms that have hit India since February this year have been quantitatively and qualitatively different from those in the past.', 'Maximum temperatures across northern and western India have been far higher than normal since April this year.']
#
# different  :  ['But, the dust storms that have hit India since February this year have been quantitatively and qualitatively different from those in the past.']
#
# past  :  ['But, the dust storms that have hit India since February this year have been quantitatively and qualitatively different from those in the past.']
#
# hit  :  ['But, the dust storms that have hit India since February this year have been quantitatively and qualitatively different from those in the past.']
#
# agricultural  :  ['For the next two decades, agricultural land grew manifold and farmers undertook extensive deep ploughing of the topsoil with the help of tractors to plant crops like wheat.', 'Waves of European settlers arrived at the beginning of the 20th century and converted grasslands into agricultural fields.', 'They are high-powered storms travelling long distances and destroying properties and agricultural fields.']
#
# destroying  :  ['They are high-powered storms travelling long distances and destroying properties and agricultural fields.']
#
# powered  :  ['They are high-powered storms travelling long distances and destroying properties and agricultural fields.']
#
# properties  :  ['They are high-powered storms travelling long distances and destroying properties and agricultural fields.']
#
# fields  :  ['They are high-powered storms travelling long distances and destroying properties and agricultural fields.']
#
# distances  :  ['They are high-powered storms travelling long distances and destroying properties and agricultural fields.']
#
# long  :  ['They are high-powered storms travelling long distances and destroying properties and agricultural fields.']
#
# high  :  ['They are high-powered storms travelling long distances and destroying properties and agricultural fields.']
#
# travelling  :  ['They are high-powered storms travelling long distances and destroying properties and agricultural fields.']
#
# affected  :  ['Since February, they have affected as many as 16 states and killed more than 500 people.']
#
# 500  :  ['Since February, they have affected as many as 16 states and killed more than 500 people.']
#
# killed  :  ['Since February, they have affected as many as 16 states and killed more than 500 people.']
#
# delhi  :  ['The Standardized Precipitation Index (SPI), which specifies the level of dryness or excess rains in an area, of large parts of Haryana, Punjab and Delhi has been negative since 2012.', 'In fact, large parts of Haryana, Punjab, Delhi and western UP have experienced mildly dry to extremely dry conditions in the last six years.', 'Cities like Delhi were choked in dust for days, with air quality level reaching the “severe” category on most days.', 'Else, we will see more intense dust storms, and a choked Delhi would be a permanent feature.']
#
# air  :  ['Cities like Delhi were choked in dust for days, with air quality level reaching the “severe” category on most days.']
#
# cities  :  ['Cities like Delhi were choked in dust for days, with air quality level reaching the “severe” category on most days.']
#
# like  :  ['Cities like Delhi were choked in dust for days, with air quality level reaching the “severe” category on most days.']
#
# quality  :  ['Cities like Delhi were choked in dust for days, with air quality level reaching the “severe” category on most days.']
#
# category  :  ['Cities like Delhi were choked in dust for days, with air quality level reaching the “severe” category on most days.']
#
# arid  :  ['The Dust Bowl areas of the Great Plains are largely arid and semi-arid and prone to extended periods of drought.', 'The dust storm regions of India and Pakistan too are largely arid and semi-arid.']
#
# drought  :  ['Successive waves of drought, which started in 1930 and ended in 1939, turned the Great Plains into bone-dry land.', 'The Dust Bowl areas of the Great Plains are largely arid and semi-arid and prone to extended periods of drought.', 'First, this area too is prone to prolonged drought.', 'Then, the drought struck.']
#
# areas  :  ['Large-scale shelterbelt plantations, contour ploughing, conservation agriculture and establishment of conservation areas to keep millions of acres as grassland, helped halt wind erosion and dust storms.', 'The Dust Bowl areas of the Great Plains are largely arid and semi-arid and prone to extended periods of drought.', 'In most of these areas, the soil has been depleted and groundwater levels have fallen precipitously.']
#
# prone  :  ['The Dust Bowl areas of the Great Plains are largely arid and semi-arid and prone to extended periods of drought.', 'First, this area too is prone to prolonged drought.']
#
# periods  :  ['The Dust Bowl areas of the Great Plains are largely arid and semi-arid and prone to extended periods of drought.']
#
# largely  :  ['The Dust Bowl areas of the Great Plains are largely arid and semi-arid and prone to extended periods of drought.', 'The dust storm regions of India and Pakistan too are largely arid and semi-arid.']
#
# semi  :  ['The Dust Bowl areas of the Great Plains are largely arid and semi-arid and prone to extended periods of drought.', 'The dust storm regions of India and Pakistan too are largely arid and semi-arid.']
#
# agriculture  :  ['Large-scale shelterbelt plantations, contour ploughing, conservation agriculture and establishment of conservation areas to keep millions of acres as grassland, helped halt wind erosion and dust storms.', 'The US federal government encouraged settlement and development of large-scale agriculture by giving large parcels of grasslands to settlers.', 'Over the last 50 years, chemical- and water-intensive agriculture has replaced the traditional low-input agriculture.', 'In addition, mechanized agriculture has led to deeper ploughing, loosening more and more topsoil.']
#
# grasslands  :  ['The US federal government encouraged settlement and development of large-scale agriculture by giving large parcels of grasslands to settlers.', 'Waves of European settlers arrived at the beginning of the 20th century and converted grasslands into agricultural fields.']
#
# settlers  :  ['The US federal government encouraged settlement and development of large-scale agriculture by giving large parcels of grasslands to settlers.', 'Waves of European settlers arrived at the beginning of the 20th century and converted grasslands into agricultural fields.']
#
# settlement  :  ['The US federal government encouraged settlement and development of large-scale agriculture by giving large parcels of grasslands to settlers.']
#
# parcels  :  ['At the same time, technological improvements allowed rapid mechanization of farm equipment, especially tractors and combined harvesters, which made it possible to operate larger parcels of land.', 'The US federal government encouraged settlement and development of large-scale agriculture by giving large parcels of grasslands to settlers.']
#
# federal  :  ['The US federal government encouraged settlement and development of large-scale agriculture by giving large parcels of grasslands to settlers.']
#
# government  :  ['The US federal government encouraged settlement and development of large-scale agriculture by giving large parcels of grasslands to settlers.', 'The Dust Bowl led the US government to initiate a large-scale land-management and soil-conservation programme.']
#
# encouraged  :  ['The US federal government encouraged settlement and development of large-scale agriculture by giving large parcels of grasslands to settlers.']
#
# large  :  ['The US federal government encouraged settlement and development of large-scale agriculture by giving large parcels of grasslands to settlers.', 'It is time India too recognizes its own Dust Bowl and initiates a large-scale ecological restoration programme to halt it.', 'The Dust Bowl led the US government to initiate a large-scale land-management and soil-conservation programme.']
#
# giving  :  ['The US federal government encouraged settlement and development of large-scale agriculture by giving large parcels of grasslands to settlers.']
#
# century  :  ['Waves of European settlers arrived at the beginning of the 20th century and converted grasslands into agricultural fields.']
#
# european  :  ['Waves of European settlers arrived at the beginning of the 20th century and converted grasslands into agricultural fields.']
#
# waves  :  ['Waves of European settlers arrived at the beginning of the 20th century and converted grasslands into agricultural fields.', 'Successive waves of drought, which started in 1930 and ended in 1939, turned the Great Plains into bone-dry land.']
#
# 20th  :  ['Waves of European settlers arrived at the beginning of the 20th century and converted grasslands into agricultural fields.']
#
# arrived  :  ['Waves of European settlers arrived at the beginning of the 20th century and converted grasslands into agricultural fields.']
#
# beginning  :  ['Waves of European settlers arrived at the beginning of the 20th century and converted grasslands into agricultural fields.']
#
# converted  :  ['Waves of European settlers arrived at the beginning of the 20th century and converted grasslands into agricultural fields.']
#
# tractors  :  ['At the same time, technological improvements allowed rapid mechanization of farm equipment, especially tractors and combined harvesters, which made it possible to operate larger parcels of land.', 'For the next two decades, agricultural land grew manifold and farmers undertook extensive deep ploughing of the topsoil with the help of tractors to plant crops like wheat.']
#
# farm  :  ['At the same time, technological improvements allowed rapid mechanization of farm equipment, especially tractors and combined harvesters, which made it possible to operate larger parcels of land.']
#
# mechanization  :  ['At the same time, technological improvements allowed rapid mechanization of farm equipment, especially tractors and combined harvesters, which made it possible to operate larger parcels of land.']
#
# equipment  :  ['At the same time, technological improvements allowed rapid mechanization of farm equipment, especially tractors and combined harvesters, which made it possible to operate larger parcels of land.']
#
# harvesters  :  ['At the same time, technological improvements allowed rapid mechanization of farm equipment, especially tractors and combined harvesters, which made it possible to operate larger parcels of land.']
#
# technological  :  ['At the same time, technological improvements allowed rapid mechanization of farm equipment, especially tractors and combined harvesters, which made it possible to operate larger parcels of land.']
#
# improvements  :  ['At the same time, technological improvements allowed rapid mechanization of farm equipment, especially tractors and combined harvesters, which made it possible to operate larger parcels of land.']
#
# larger  :  ['At the same time, technological improvements allowed rapid mechanization of farm equipment, especially tractors and combined harvesters, which made it possible to operate larger parcels of land.']
#
# ploughing  :  ['Large-scale shelterbelt plantations, contour ploughing, conservation agriculture and establishment of conservation areas to keep millions of acres as grassland, helped halt wind erosion and dust storms.', 'For the next two decades, agricultural land grew manifold and farmers undertook extensive deep ploughing of the topsoil with the help of tractors to plant crops like wheat.', 'As the soil was already loose due to extensive ploughing, high winds turned them to dust and blew them away in huge clouds.', 'In addition, mechanized agriculture has led to deeper ploughing, loosening more and more topsoil.']
#
# crops  :  ['For the next two decades, agricultural land grew manifold and farmers undertook extensive deep ploughing of the topsoil with the help of tractors to plant crops like wheat.']
#
# topsoil  :  ['For the next two decades, agricultural land grew manifold and farmers undertook extensive deep ploughing of the topsoil with the help of tractors to plant crops like wheat.', 'In addition, mechanized agriculture has led to deeper ploughing, loosening more and more topsoil.']
#
# farmers  :  ['For the next two decades, agricultural land grew manifold and farmers undertook extensive deep ploughing of the topsoil with the help of tractors to plant crops like wheat.']
#
# wheat  :  ['For the next two decades, agricultural land grew manifold and farmers undertook extensive deep ploughing of the topsoil with the help of tractors to plant crops like wheat.']
#
# grew  :  ['For the next two decades, agricultural land grew manifold and farmers undertook extensive deep ploughing of the topsoil with the help of tractors to plant crops like wheat.']
#
# plant  :  ['For the next two decades, agricultural land grew manifold and farmers undertook extensive deep ploughing of the topsoil with the help of tractors to plant crops like wheat.']
#
# grasses  :  ['This displaced the native, deep-rooted grasses that trapped soil and moisture even during dry periods and high winds.']
#
# moisture  :  ['This displaced the native, deep-rooted grasses that trapped soil and moisture even during dry periods and high winds.']
#
# winds  :  ['As the soil was already loose due to extensive ploughing, high winds turned them to dust and blew them away in huge clouds.', 'Last, climate change is affecting the pattern of Western Disturbances (WDs), leading to stronger winds and stronger storms.', 'This displaced the native, deep-rooted grasses that trapped soil and moisture even during dry periods and high winds.']
#
# rooted  :  ['This displaced the native, deep-rooted grasses that trapped soil and moisture even during dry periods and high winds.']
#
# dry  :  ['In fact, large parts of Haryana, Punjab, Delhi and western UP have experienced mildly dry to extremely dry conditions in the last six years.', 'This displaced the native, deep-rooted grasses that trapped soil and moisture even during dry periods and high winds.', 'Successive waves of drought, which started in 1930 and ended in 1939, turned the Great Plains into bone-dry land.']
#
# displaced  :  ['This displaced the native, deep-rooted grasses that trapped soil and moisture even during dry periods and high winds.']
#
# trapped  :  ['This displaced the native, deep-rooted grasses that trapped soil and moisture even during dry periods and high winds.']
#
# deep  :  ['This displaced the native, deep-rooted grasses that trapped soil and moisture even during dry periods and high winds.']
#
# native  :  ['This displaced the native, deep-rooted grasses that trapped soil and moisture even during dry periods and high winds.']
#
# struck  :  ['Then, the drought struck.']
#
# 1930  :  ['Successive waves of drought, which started in 1930 and ended in 1939, turned the Great Plains into bone-dry land.']
#
# 1939  :  ['Successive waves of drought, which started in 1930 and ended in 1939, turned the Great Plains into bone-dry land.']
#
# bone  :  ['Successive waves of drought, which started in 1930 and ended in 1939, turned the Great Plains into bone-dry land.']
#
# started  :  ['Successive waves of drought, which started in 1930 and ended in 1939, turned the Great Plains into bone-dry land.']
#
# ended  :  ['Successive waves of drought, which started in 1930 and ended in 1939, turned the Great Plains into bone-dry land.']
#
# clouds  :  ['As the soil was already loose due to extensive ploughing, high winds turned them to dust and blew them away in huge clouds.']
#
# blew  :  ['As the soil was already loose due to extensive ploughing, high winds turned them to dust and blew them away in huge clouds.']
#
# loose  :  ['As the soil was already loose due to extensive ploughing, high winds turned them to dust and blew them away in huge clouds.']
#
# huge  :  ['As the soil was already loose due to extensive ploughing, high winds turned them to dust and blew them away in huge clouds.']
#
# away  :  ['As the soil was already loose due to extensive ploughing, high winds turned them to dust and blew them away in huge clouds.']
#
# turned  :  ['As the soil was already loose due to extensive ploughing, high winds turned them to dust and blew them away in huge clouds.']
#
# familiar  :  ['Does this sound familiar?']
#
# does  :  ['Does this sound familiar?']
#
# sound  :  ['Does this sound familiar?']
#
# pakistan  :  ['The dust storm regions of India and Pakistan too are largely arid and semi-arid.']
#
# storm  :  ['The dust storm regions of India and Pakistan too are largely arid and semi-arid.']
#
# regions  :  ['The dust storm regions of India and Pakistan too are largely arid and semi-arid.']
#
# windy  :  ['But they are at a lower altitude and hence less windy compared to the Great Plains.']
#
# altitude  :  ['But they are at a lower altitude and hence less windy compared to the Great Plains.']
#
# compared  :  ['But they are at a lower altitude and hence less windy compared to the Great Plains.']
#
# lower  :  ['But they are at a lower altitude and hence less windy compared to the Great Plains.']
#
# great  :  ['But they are at a lower altitude and hence less windy compared to the Great Plains.']
#
# traditional  :  ['Over the last 50 years, chemical- and water-intensive agriculture has replaced the traditional low-input agriculture.']
#
# water  :  ['Over the last 50 years, chemical- and water-intensive agriculture has replaced the traditional low-input agriculture.']
#
# input  :  ['Over the last 50 years, chemical- and water-intensive agriculture has replaced the traditional low-input agriculture.']
#
# chemical  :  ['Over the last 50 years, chemical- and water-intensive agriculture has replaced the traditional low-input agriculture.']
#
# replaced  :  ['Over the last 50 years, chemical- and water-intensive agriculture has replaced the traditional low-input agriculture.']
#
# years  :  ['Over the last 50 years, chemical- and water-intensive agriculture has replaced the traditional low-input agriculture.']
#
# intensive  :  ['Over the last 50 years, chemical- and water-intensive agriculture has replaced the traditional low-input agriculture.']
#
# irrigation  :  ['Canal irrigation has been overtaken by the groundwater irrigation.']
#
# groundwater  :  ['In most of these areas, the soil has been depleted and groundwater levels have fallen precipitously.', 'Canal irrigation has been overtaken by the groundwater irrigation.', 'The result has been devastating for the soil and groundwater.']
#
# canal  :  ['Canal irrigation has been overtaken by the groundwater irrigation.']
#
# overtaken  :  ['Canal irrigation has been overtaken by the groundwater irrigation.']
#
# mechanized  :  ['In addition, mechanized agriculture has led to deeper ploughing, loosening more and more topsoil.']
#
# loosening  :  ['In addition, mechanized agriculture has led to deeper ploughing, loosening more and more topsoil.']
#
# deeper  :  ['In addition, mechanized agriculture has led to deeper ploughing, loosening more and more topsoil.']
#
# addition  :  ['In addition, mechanized agriculture has led to deeper ploughing, loosening more and more topsoil.']
#
# led  :  ['In addition, mechanized agriculture has led to deeper ploughing, loosening more and more topsoil.']
#
# devastating  :  ['The result has been devastating for the soil and groundwater.']
#
# result  :  ['The result has been devastating for the soil and groundwater.']
#
# depleted  :  ['In most of these areas, the soil has been depleted and groundwater levels have fallen precipitously.']
#
# precipitously  :  ['In most of these areas, the soil has been depleted and groundwater levels have fallen precipitously.']
#
# fallen  :  ['In most of these areas, the soil has been depleted and groundwater levels have fallen precipitously.']
#
# levels  :  ['In most of these areas, the soil has been depleted and groundwater levels have fallen precipitously.']
#
# climatic  :  ['On top of the man-made ecological destruction, the natural climatic cycle along with climate change is affecting the weather pattern of this region.']
#
# climate  :  ['On top of the man-made ecological destruction, the natural climatic cycle along with climate change is affecting the weather pattern of this region.', 'Last, climate change is affecting the pattern of Western Disturbances (WDs), leading to stronger winds and stronger storms.']
#
# destruction  :  ['On top of the man-made ecological destruction, the natural climatic cycle along with climate change is affecting the weather pattern of this region.']
#
# cycle  :  ['On top of the man-made ecological destruction, the natural climatic cycle along with climate change is affecting the weather pattern of this region.']
#
# pattern  :  ['On top of the man-made ecological destruction, the natural climatic cycle along with climate change is affecting the weather pattern of this region.']
#
# affecting  :  ['On top of the man-made ecological destruction, the natural climatic cycle along with climate change is affecting the weather pattern of this region.', 'Last, climate change is affecting the pattern of Western Disturbances (WDs), leading to stronger winds and stronger storms.']
#
# region  :  ['On top of the man-made ecological destruction, the natural climatic cycle along with climate change is affecting the weather pattern of this region.', 'WDs are storms originating in the Mediterranean region that bring winter rain to northwestern India.']
#
# natural  :  ['On top of the man-made ecological destruction, the natural climatic cycle along with climate change is affecting the weather pattern of this region.']
#
# area  :  ['Second, this area is experiencing increasing temperatures.', 'First, this area too is prone to prolonged drought.']
#
# prolonged  :  ['First, this area too is prone to prolonged drought.']
#
# conditions  :  ['In fact, large parts of Haryana, Punjab, Delhi and western UP have experienced mildly dry to extremely dry conditions in the last six years.']
#
# western  :  ['In fact, large parts of Haryana, Punjab, Delhi and western UP have experienced mildly dry to extremely dry conditions in the last six years.', 'Last, climate change is affecting the pattern of Western Disturbances (WDs), leading to stronger winds and stronger storms.', 'Maximum temperatures across northern and western India have been far higher than normal since April this year.']
#
# mildly  :  ['In fact, large parts of Haryana, Punjab, Delhi and western UP have experienced mildly dry to extremely dry conditions in the last six years.']
#
# extremely  :  ['In fact, large parts of Haryana, Punjab, Delhi and western UP have experienced mildly dry to extremely dry conditions in the last six years.']
#
# spi  :  ['The Standardized Precipitation Index (SPI), which specifies the level of dryness or excess rains in an area, of large parts of Haryana, Punjab and Delhi has been negative since 2012.', 'Rajasthan, on the other hand shows a positive SPI or excess rainfall.']
#
# precipitation  :  ['The Standardized Precipitation Index (SPI), which specifies the level of dryness or excess rains in an area, of large parts of Haryana, Punjab and Delhi has been negative since 2012.']
#
# dryness  :  ['The Standardized Precipitation Index (SPI), which specifies the level of dryness or excess rains in an area, of large parts of Haryana, Punjab and Delhi has been negative since 2012.']
#
# index  :  ['The Standardized Precipitation Index (SPI), which specifies the level of dryness or excess rains in an area, of large parts of Haryana, Punjab and Delhi has been negative since 2012.']
#
# negative  :  ['The Standardized Precipitation Index (SPI), which specifies the level of dryness or excess rains in an area, of large parts of Haryana, Punjab and Delhi has been negative since 2012.']
#
# standardized  :  ['The Standardized Precipitation Index (SPI), which specifies the level of dryness or excess rains in an area, of large parts of Haryana, Punjab and Delhi has been negative since 2012.']
#
# rainfall  :  ['Rajasthan, on the other hand shows a positive SPI or excess rainfall.']
#
# positive  :  ['Rajasthan, on the other hand shows a positive SPI or excess rainfall.']
#
# excess  :  ['Rajasthan, on the other hand shows a positive SPI or excess rainfall.']
#
# shows  :  ['Rajasthan, on the other hand shows a positive SPI or excess rainfall.']
#
# hand  :  ['Rajasthan, on the other hand shows a positive SPI or excess rainfall.']
#
# increasing  :  ['Second, this area is experiencing increasing temperatures.']
#
# second  :  ['Second, this area is experiencing increasing temperatures.']
#
# experiencing  :  ['Second, this area is experiencing increasing temperatures.']
#
# temperature  :  ['In fact, there seems to be a strong correlation between the dust storms and the rapid increase in temperature.']
#
# correlation  :  ['In fact, there seems to be a strong correlation between the dust storms and the rapid increase in temperature.']
#
# increase  :  ['In fact, there seems to be a strong correlation between the dust storms and the rapid increase in temperature.']
#
# rapid  :  ['In fact, there seems to be a strong correlation between the dust storms and the rapid increase in temperature.']
#
# strong  :  ['In fact, there seems to be a strong correlation between the dust storms and the rapid increase in temperature.']
#
# maximum  :  ['Maximum temperatures across northern and western India have been far higher than normal since April this year.']
#
# april  :  ['Maximum temperatures across northern and western India have been far higher than normal since April this year.']
#
# northern  :  ['Maximum temperatures across northern and western India have been far higher than normal since April this year.']
#
# higher  :  ['Maximum temperatures across northern and western India have been far higher than normal since April this year.']
#
# normal  :  ['Maximum temperatures across northern and western India have been far higher than normal since April this year.']
#
# far  :  ['Maximum temperatures across northern and western India have been far higher than normal since April this year.']
#
# disturbances  :  ['Last, climate change is affecting the pattern of Western Disturbances (WDs), leading to stronger winds and stronger storms.']
#
# wds  :  ['But because of the warming of the Arctic and the Tibetan Plateau, indications are that the WDs are becoming unseasonal, frequent and stronger.', 'Last, climate change is affecting the pattern of Western Disturbances (WDs), leading to stronger winds and stronger storms.', 'WDs are storms originating in the Mediterranean region that bring winter rain to northwestern India.']
#
# change  :  ['Last, climate change is affecting the pattern of Western Disturbances (WDs), leading to stronger winds and stronger storms.']
#
# stronger  :  ['But because of the warming of the Arctic and the Tibetan Plateau, indications are that the WDs are becoming unseasonal, frequent and stronger.', 'Last, climate change is affecting the pattern of Western Disturbances (WDs), leading to stronger winds and stronger storms.']
#
# leading  :  ['Last, climate change is affecting the pattern of Western Disturbances (WDs), leading to stronger winds and stronger storms.']
#
# rain  :  ['WDs are storms originating in the Mediterranean region that bring winter rain to northwestern India.']
#
# winter  :  ['WDs are storms originating in the Mediterranean region that bring winter rain to northwestern India.']
#
# mediterranean  :  ['WDs are storms originating in the Mediterranean region that bring winter rain to northwestern India.']
#
# originating  :  ['WDs are storms originating in the Mediterranean region that bring winter rain to northwestern India.']
#
# northwestern  :  ['WDs are storms originating in the Mediterranean region that bring winter rain to northwestern India.']
#
# arctic  :  ['But because of the warming of the Arctic and the Tibetan Plateau, indications are that the WDs are becoming unseasonal, frequent and stronger.']
#
# tibetan  :  ['But because of the warming of the Arctic and the Tibetan Plateau, indications are that the WDs are becoming unseasonal, frequent and stronger.']
#
# warming  :  ['But because of the warming of the Arctic and the Tibetan Plateau, indications are that the WDs are becoming unseasonal, frequent and stronger.']
#
# plateau  :  ['But because of the warming of the Arctic and the Tibetan Plateau, indications are that the WDs are becoming unseasonal, frequent and stronger.']
#
# unseasonal  :  ['But because of the warming of the Arctic and the Tibetan Plateau, indications are that the WDs are becoming unseasonal, frequent and stronger.']
#
# frequent  :  ['But because of the warming of the Arctic and the Tibetan Plateau, indications are that the WDs are becoming unseasonal, frequent and stronger.']
#
# indications  :  ['But because of the warming of the Arctic and the Tibetan Plateau, indications are that the WDs are becoming unseasonal, frequent and stronger.']
#
# conservation  :  ['Large-scale shelterbelt plantations, contour ploughing, conservation agriculture and establishment of conservation areas to keep millions of acres as grassland, helped halt wind erosion and dust storms.', 'The Dust Bowl led the US government to initiate a large-scale land-management and soil-conservation programme.']
#
# management  :  ['The Dust Bowl led the US government to initiate a large-scale land-management and soil-conservation programme.']
#
# scale  :  ['The Dust Bowl led the US government to initiate a large-scale land-management and soil-conservation programme.']
#
# programme  :  ['It is time India too recognizes its own Dust Bowl and initiates a large-scale ecological restoration programme to halt it.', 'The Dust Bowl led the US government to initiate a large-scale land-management and soil-conservation programme.']
#
# grassland  :  ['Large-scale shelterbelt plantations, contour ploughing, conservation agriculture and establishment of conservation areas to keep millions of acres as grassland, helped halt wind erosion and dust storms.']
#
# plantations  :  ['Large-scale shelterbelt plantations, contour ploughing, conservation agriculture and establishment of conservation areas to keep millions of acres as grassland, helped halt wind erosion and dust storms.']
#
# shelterbelt  :  ['Large-scale shelterbelt plantations, contour ploughing, conservation agriculture and establishment of conservation areas to keep millions of acres as grassland, helped halt wind erosion and dust storms.']
#
# erosion  :  ['Large-scale shelterbelt plantations, contour ploughing, conservation agriculture and establishment of conservation areas to keep millions of acres as grassland, helped halt wind erosion and dust storms.']
#
# wind  :  ['Large-scale shelterbelt plantations, contour ploughing, conservation agriculture and establishment of conservation areas to keep millions of acres as grassland, helped halt wind erosion and dust storms.']
#
# restoration  :  ['It is time India too recognizes its own Dust Bowl and initiates a large-scale ecological restoration programme to halt it.']
#
# halt  :  ['It is time India too recognizes its own Dust Bowl and initiates a large-scale ecological restoration programme to halt it.']
#
# recognizes  :  ['It is time India too recognizes its own Dust Bowl and initiates a large-scale ecological restoration programme to halt it.']
#
# time  :  ['It is time India too recognizes its own Dust Bowl and initiates a large-scale ecological restoration programme to halt it.']
#
# permanent  :  ['Else, we will see more intense dust storms, and a choked Delhi would be a permanent feature.']
#
# feature  :  ['Else, we will see more intense dust storms, and a choked Delhi would be a permanent feature.']
#
# intense  :  ['Else, we will see more intense dust storms, and a choked Delhi would be a permanent feature.']

# %% [markdown]
# ## Generating Distractors with BERT

# %%
# load BERT model
from transformers import pipeline
unmasker = pipeline('fill-mask', model='distilbert-base-uncased')
# Out:
# Downloading:   0%|          | 0.00/483 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/256M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/455k [00:00<?, ?B/s]

# %%
import random

def get_questions(keyword_to_sentences_map, model, k=5):
    """"
    Generates questions along with distractors
    @input keyword_to_sentences_map : maps keywords to sentences they appear in
    @model: BERT model that will be used to mask the keyword and generate distractors
    @k (default 5), number of questions to return
    """

    # we can choose answer keys randomly from the pool of keywords
    keys = random.choices( list(keyword_to_sentences_map.keys()), k=k)

    for word in keys:
        answer = word
        #print(get_question(answer, context))
        questions = keyword_to_sentences_map[word]
        q = max(questions, key=len)

        a = q.lower().find(answer)
        b = a + len(answer)
        q = q.replace(q[a:b], '_____')

        results= model(q.replace('_____', '[MASK]'))
        #print(results)

        options = [result['token_str'] for result in results if isinstance(result, dict) and (answer not in result['token_str'].lower())]

        if options:
            print(q)
            print(f'Ans: {answer}')
            print(options)
            print()


get_questions(keyword_to_sentences_map, unmasker, 10)
# Out:
# This displaced the _____, deep-rooted grasses that trapped soil and moisture even during dry periods and high winds.
# Ans: native
# ['dense', 'thick', 'tall', 'coarse', 'thin']
#
# The storms damaged the soil in around 100 million acres of land, leading to the greatest short-time migration in the American history, with approximately 3.5 million people _____ their farms and fields.
# Ans: abandoning
# ['leaving', 'losing', 'fleeing', 'destroying']
#
# In fact, people welcome dust storms as they bring down temperatures and herald the arrival of the _____.
# Ans: monsoons
# ['monsoon', 'sun', 'moon', 'rain', 'comet']
#
# But, the dust storms that have hit India since February this year have been quantitatively and qualitatively different from those in the _____.
# Ans: past
# ['caribbean', 'himalayas', 'philippines', 'west']
#
# Else, we will see more _____ dust storms, and a choked Delhi would be a permanent feature.
# Ans: intense
# ['frequent', 'severe', 'recent', 'permanent']
#
# Large-scale shelterbelt plantations, contour ploughing, conservation agriculture and establishment of conservation areas to keep millions of acres as grassland, helped halt _____ erosion and dust storms.
# Ans: wind
# ['soil', 'coastal', 'crop', 'agricultural']
#
# Over the last 50 years, chemical- and water-intensive agriculture has _____ the traditional low-input agriculture.
# Ans: replaced
# ['displaced', 'superseded', 'surpassed', 'eliminated']
#
# It is time India too recognizes its own Dust Bowl and initiates a large-scale ecological restoration programme to _____ it.
# Ans: halt
# ['conserve', 'preserve', 'restore', 'protect', 'save']
#
# In most of these areas, the soil has been depleted and _____ levels have fallen precipitously.
# Ans: groundwater
# ['water', 'nutrient', 'phosphorus', 'oxygen']

# %%
# !mkdir -p src

# %%
# %%writefile src/answerkey.py
from sentence_transformers import SentenceTransformer
from keybert import KeyBERT
from nltk.tokenize import sent_tokenize
import nltk
# we use nltk library to tokenize our text
nltk.download('punkt')

class AnswerKey:
    """
    Generate answers using keyword extraction, and map them to sentences they appear in
    """

    def __init__(self, text):
        self.text = text

        # KeyBert uses BERT-embeddings and simple cosine similarity to find the sub-phrases in a document that are the most similar to the document itself.
        sentence_model = SentenceTransformer("all-MiniLM-L6-v2")
        self.kw_model = KeyBERT(sentence_model)

    def get_keywords(self, text):
        """
        Given @input text, identify important keywords. 
        Here we use Sentence Transformer to extract keywords that best describe the text
        """
        keywords_with_scores = self.kw_model.extract_keywords(text, keyphrase_ngram_range=(1, 2), top_n=5, stop_words='english')
        keywords = [kw[0] for kw in keywords_with_scores]
        scores = [kw[1] for kw in keywords_with_scores]
        return keywords

    def tokenize_sentences(self, text):
        """
        Given a @text input, returns tokenized sentences
        """
        sentences = [sent_tokenize(text)]
        sentences = [sentence for paragraph in sentences for sentence in paragraph]

        # Remove sentences shorter than 20 letters.
        sentences = [sentence.strip() for sentence in sentences if len(sentence) > 20]
        return sentences

    def get_sentences_for_keyword(self, kw_model, sentences, ngram_range=(1, 1), top_n=10):
        """
        @kw_model: keyBERT model to extract keywords
        @sentences: list of tokenized sentences
        returns a map with keywords as keys mapped to the sentences they appear in.
        """
        keyword_sentences = {}
        for sentence in sentences:
            keywords_found = [kw[0] for kw in kw_model.extract_keywords(sentence, keyphrase_ngram_range=ngram_range, top_n=top_n) if len(kw[0]) > 2]

            for key in keywords_found:
                keyword_sentences[key] = keyword_sentences.get(key, [])
                keyword_sentences[key].append(sentence)

        return keyword_sentences

    def get_answers(self, ngram_range=(1, 2), top_n=10):
        sentences = self.tokenize_sentences(self.text)
        keyword_to_sentences = self.get_sentences_for_keyword(self.kw_model, sentences, ngram_range=ngram_range, top_n=top_n)
        return keyword_to_sentences
# Out:
# Writing src/answerkey.py

# %%
# %%writefile src/t5model.py

import requests
import json

API_URL = "https://api-inference.huggingface.co/models/mrm8488/t5-base-finetuned-question-generation-ap"

with open('../.env') as f:
    API_TOKEN = str(f.read()).strip('\n')
    API_TOKEN = API_TOKEN.strip()
    
headers = {"Authorization": f"{API_TOKEN}"}

def query(payload):
    response = requests.post(API_URL, headers=headers, json=payload)
    output =  json.loads(response.content.decode("utf-8"))
    return output

# ping model to wake it up when this package is imported
print(query("answer: Manuel context: Manuel has created RuPERTa-base with the support of HF-Transformers and Google"))
# Out:
# Overwriting src/t5model.py

# %%
# %%writefile src/model.py

from transformers import pipeline
from .t5model import query
import random


# load BERT model once
unmasker = pipeline('fill-mask', model='distilbert-base-uncased')


class Model:

    def get_questions(self, keyword_to_sentences_map, model, k=5, declarative=True):
        """"
        Generates questions along with distractors
        @input keyword_to_sentences_map : maps keywords to sentences they appear in
        @model: BERT model that will be used to mask the keyword and generate distractors
        @k (default 5), number of questions to return
        """

        results = []

        # we can choose answer keys randomly from the pool of keywords
        answer_keys = random.choices( list(keyword_to_sentences_map.keys()), k=k)

        for answer in answer_keys:
            sentences = keyword_to_sentences_map[answer]
            sentence = max(sentences, key=len)

            if len(sentence) < 20:
                continue

            start_idx = sentence.lower().find(answer)
            end_idx = start_idx + len(answer)

            # replace answer in sentence with blank line to form question
            question = sentence.replace(sentence[start_idx: end_idx], '__________')

            # generate distractors from BERT model 
            distractors = model(question.replace('__________', '[MASK]'))
            options = [option['token_str'] for option in distractors if isinstance(option, dict) and (answer not in option['token_str'].lower())]
            #print(distractors)

            # generate question
            if not declarative:
                context = sentence
                output = query(f"answer: {answer} context: {context}")
                question_t5 = output[0]["generated_text"]

                if options:
                    results.append((question_t5, options, answer))
            else:
                if options:
                    results.append((question, options, answer))

        return results
# Out:
# Overwriting src/model.py

# %%
# %%writefile app.py

from src.answerkey import AnswerKey
from src.model import Model, unmasker
import streamlit as st

PAGE_CONFIG = {"page_title":"MCQ-App by Glad Nayak","page_icon":":white_check_mark:"}
st.set_page_config(**PAGE_CONFIG)

def render_input():
    """
    Renders text area for input, and button
    """
    # source of default text: https://www.fresherslive.com/online-test/reading-comprehension-test-questions-and-answers
    text = """The Dust Bowl, considered one of the greatest man-made ecological disasters, was a period of severe dust storms that lasted nearly a decade, starting 1931, and engulfed large parts of the US. The dust storms originated in the Great Plains-from states like Texas, Oklahoma, New Mexico, Colorado and Kansas. They were so severe that they choked everything and blocked out the sun for days. Sometimes, the storms travelled thousands of kilometres and blotted out monuments such as the Statue of Liberty. Citizens developed “dust pneumonia” and experienced chest pain and difficulty in breathing. The storms damaged the soil in around 100 million acres of land, leading to the greatest short-time migration in the American history, with approximately 3.5 million people abandoning their farms and fields.

    Dust storms are an annual weather pattern in the northern region of India comprising Delhi, Haryana, Punjab, Uttar Pradesh and Rajasthan and Punjab, as also in the Sindh region of Pakistan. But, they are normally low in intensity and accompanied by rains. In fact, people welcome dust storms as they bring down temperatures and herald the arrival of the monsoons. But, the dust storms that have hit India since February this year have been quantitatively and qualitatively different from those in the past. They are high-powered storms travelling long distances and destroying properties and agricultural fields. Since February, they have affected as many as 16 states and killed more than 500 people. Cities like Delhi were choked in dust for days, with air quality level reaching the “severe” category on most days.

    The Dust Bowl areas of the Great Plains are largely arid and semi-arid and prone to extended periods of drought. The US federal government encouraged settlement and development of large-scale agriculture by giving large parcels of grasslands to settlers. Waves of European settlers arrived at the beginning of the 20th century and converted grasslands into agricultural fields. At the same time, technological improvements allowed rapid mechanization of farm equipment, especially tractors and combined harvesters, which made it possible to operate larger parcels of land.

    For the next two decades, agricultural land grew manifold and farmers undertook extensive deep ploughing of the topsoil with the help of tractors to plant crops like wheat. This displaced the native, deep-rooted grasses that trapped soil and moisture even during dry periods and high winds. Then, the drought struck. Successive waves of drought, which started in 1930 and ended in 1939, turned the Great Plains into bone-dry land. As the soil was already loose due to extensive ploughing, high winds turned them to dust and blew them away in huge clouds. Does this sound familiar? The dust storm regions of India and Pakistan too are largely arid and semi-arid. But they are at a lower altitude and hence less windy compared to the Great Plains. Over the last 50 years, chemical- and water-intensive agriculture has replaced the traditional low-input agriculture. Canal irrigation has been overtaken by the groundwater irrigation. In addition, mechanized agriculture has led to deeper ploughing, loosening more and more topsoil. The result has been devastating for the soil and groundwater. In most of these areas, the soil has been depleted and groundwater levels have fallen precipitously. On top of the man-made ecological destruction, the natural climatic cycle along with climate change is affecting the weather pattern of this region.

    First, this area too is prone to prolonged drought. In fact, large parts of Haryana, Punjab, Delhi and western UP have experienced mildly dry to extremely dry conditions in the last six years. The Standardized Precipitation Index (SPI), which specifies the level of dryness or excess rains in an area, of large parts of Haryana, Punjab and Delhi has been negative since 2012. Rajasthan, on the other hand shows a positive SPI or excess rainfall. Second, this area is experiencing increasing temperatures. In fact, there seems to be a strong correlation between the dust storms and the rapid increase in temperature. Maximum temperatures across northern and western India have been far higher than normal since April this year. Last, climate change is affecting the pattern of Western Disturbances (WDs), leading to stronger winds and stronger storms. WDs are storms originating in the Mediterranean region that bring winter rain to northwestern India. But because of the warming of the Arctic and the Tibetan Plateau, indications are that the WDs are becoming unseasonal, frequent and stronger.

    The Dust Bowl led the US government to initiate a large-scale land-management and soil-conservation programme. Large-scale shelterbelt plantations, contour ploughing, conservation agriculture and establishment of conservation areas to keep millions of acres as grassland, helped halt wind erosion and dust storms. It is time India too recognizes its own Dust Bowl and initiates a large-scale ecological restoration programme to halt it. Else, we will see more intense dust storms, and a choked Delhi would be a permanent feature.
    """
    st.sidebar.subheader('Enter Text:')
    text = st.sidebar.text_area('', text.strip(), height = 275)

    ngram_range = st.sidebar.slider('answer ngram range:', value=[1, 2], min_value=1, max_value=3, step=1)
    num_questions = st.sidebar.slider("number of questions:", value=10, min_value=10, max_value=20, step=1)
    question_type_str = st.sidebar.radio('question type:', ('declarative (fill in the blanks)', 'imperative'))
    question_type = question_type_str == 'declarative (fill in the blanks)'

    button = st.sidebar.button('Generate')

    if button:
        return (text, ngram_range, num_questions, question_type)

def main():
    # Render input text area
    inputs = render_input()

    if not inputs:
        st.title('Generate Multiple Choice Questions(MCQs) from Text Automatically')
        st.subheader('Enter Text, select how long a single answer should be(ngram_range), and number of questions to get started.')

    else:
        with st.spinner('Loading questions and distractors using BERT model'):
            st.subheader("")
            st.title("")
            text, ngram_range, num_questions, question_type = inputs

            # Load model
            answerkeys = AnswerKey(text)
            keyword_to_sentence = answerkeys.get_answers(ngram_range, num_questions)

            model = Model()
            quizzes = model.get_questions(keyword_to_sentence, unmasker, k=num_questions, declarative=question_type)

            st.subheader('Questions')
            for id, quiz in enumerate(quizzes):
                question, options, answer = quiz
                st.write(question)

                for option in options[:3]:
                    st.checkbox(option, key=id)

                ans_button = st.checkbox(answer, key=id, value=True)

            st.balloons()
            st.button('Save')


if __name__ == '__main__':
    main()
# Out:
# Overwriting app.py

# %% [markdown]
# ## Local Deployment

# %%
# to test locally we install localtunnel
# !pip install streamlit > /dev/null
# !npm install -g localtunnel > /dev/null
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jupyter-console 5.2.0 requires prompt-toolkit<2.0.0,>=1.0.0, but you have prompt-toolkit 3.0.24 which is incompatible.
# google-colab 1.0.0 requires ipykernel~=4.10, but you have ipykernel 6.7.0 which is incompatible.
# google-colab 1.0.0 requires ipython~=5.5.0, but you have ipython 7.31.0 which is incompatible.

# %% [markdown]
# ## Generate requirements.txt and Install Requirements

# %%
# !pip install pipreqs
# Out:
# Collecting pipreqs
#   Downloading pipreqs-0.4.11-py2.py3-none-any.whl (32 kB)
# Collecting yarg
#   Downloading yarg-0.1.9-py2.py3-none-any.whl (19 kB)
# Requirement already satisfied: docopt in /usr/local/lib/python3.7/dist-packages (from pipreqs) (0.6.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from yarg->pipreqs) (2.23.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->yarg->pipreqs) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->yarg->pipreqs) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->yarg->pipreqs) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->yarg->pipreqs) (1.24.3)
# Installing collected packages: yarg, pipreqs
# Successfully installed pipreqs-0.4.11 yarg-0.1.9

# %%
# !pipreqs .
# Out:
# INFO: Successfully saved requirements file in ./requirements.txt

# %%
# !pip install -r requirements.txt
# Out:
# Collecting keybert==0.5.0
#   Downloading keybert-0.5.0.tar.gz (19 kB)
# Requirement already satisfied: nltk==3.2.5 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 2)) (3.2.5)
# Requirement already satisfied: requests==2.23.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 3)) (2.23.0)
# Collecting sentence_transformers==2.1.0
#   Downloading sentence-transformers-2.1.0.tar.gz (78 kB)
#      |████████████████████████████████| 78 kB 3.0 MB/s
# Requirement already satisfied: streamlit==1.4.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 5)) (1.4.0)
# Collecting transformers==4.15.0
#   Downloading transformers-4.15.0-py3-none-any.whl (3.4 MB)
#      |████████████████████████████████| 3.4 MB 10.6 MB/s
# Requirement already satisfied: scikit-learn>=0.22.2 in /usr/local/lib/python3.7/dist-packages (from keybert==0.5.0->-r requirements.txt (line 1)) (1.0.2)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.7/dist-packages (from keybert==0.5.0->-r requirements.txt (line 1)) (1.19.5)
# Collecting rich>=10.4.0
#   Downloading rich-11.0.0-py3-none-any.whl (215 kB)
#      |████████████████████████████████| 215 kB 56.6 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk==3.2.5->-r requirements.txt (line 2)) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests==2.23.0->-r requirements.txt (line 3)) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests==2.23.0->-r requirements.txt (line 3)) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests==2.23.0->-r requirements.txt (line 3)) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests==2.23.0->-r requirements.txt (line 3)) (2.10)
# Collecting tokenizers>=0.10.3
#   Downloading tokenizers-0.11.2-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.8 MB)
#      |████████████████████████████████| 6.8 MB 41.1 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from sentence_transformers==2.1.0->-r requirements.txt (line 4)) (4.62.3)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence_transformers==2.1.0->-r requirements.txt (line 4)) (1.10.0+cu111)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from sentence_transformers==2.1.0->-r requirements.txt (line 4)) (0.11.1+cu111)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from sentence_transformers==2.1.0->-r requirements.txt (line 4)) (1.4.1)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 55.8 MB/s
# Collecting huggingface-hub
#   Downloading huggingface_hub-0.4.0-py3-none-any.whl (67 kB)
#      |████████████████████████████████| 67 kB 4.5 MB/s
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.7/dist-packages (from streamlit==1.4.0->-r requirements.txt (line 5)) (7.1.2)
# Requirement already satisfied: altair>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from streamlit==1.4.0->-r requirements.txt (line 5)) (4.2.0)
# Requirement already satisfied: protobuf!=3.11,>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from streamlit==1.4.0->-r requirements.txt (line 5)) (3.17.3)
# Requirement already satisfied: cachetools>=4.0 in /usr/local/lib/python3.7/dist-packages (from streamlit==1.4.0->-r requirements.txt (line 5)) (4.2.4)
# Requirement already satisfied: validators in /usr/local/lib/python3.7/dist-packages (from streamlit==1.4.0->-r requirements.txt (line 5)) (0.18.2)
# Requirement already satisfied: watchdog in /usr/local/lib/python3.7/dist-packages (from streamlit==1.4.0->-r requirements.txt (line 5)) (2.1.6)
# Requirement already satisfied: pydeck>=0.1.dev5 in /usr/local/lib/python3.7/dist-packages (from streamlit==1.4.0->-r requirements.txt (line 5)) (0.7.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from streamlit==1.4.0->-r requirements.txt (line 5)) (21.3)
# Requirement already satisfied: tornado>=5.0 in /usr/local/lib/python3.7/dist-packages (from streamlit==1.4.0->-r requirements.txt (line 5)) (5.1.1)
# Requirement already satisfied: gitpython!=3.1.19 in /usr/local/lib/python3.7/dist-packages (from streamlit==1.4.0->-r requirements.txt (line 5)) (3.1.26)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from streamlit==1.4.0->-r requirements.txt (line 5)) (7.1.2)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.7/dist-packages (from streamlit==1.4.0->-r requirements.txt (line 5)) (1.5.1)
# Requirement already satisfied: blinker in /usr/local/lib/python3.7/dist-packages (from streamlit==1.4.0->-r requirements.txt (line 5)) (1.4)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.7/dist-packages (from streamlit==1.4.0->-r requirements.txt (line 5)) (3.0.0)
# Requirement already satisfied: base58 in /usr/local/lib/python3.7/dist-packages (from streamlit==1.4.0->-r requirements.txt (line 5)) (2.1.1)
# Requirement already satisfied: toml in /usr/local/lib/python3.7/dist-packages (from streamlit==1.4.0->-r requirements.txt (line 5)) (0.10.2)
# Requirement already satisfied: astor in /usr/local/lib/python3.7/dist-packages (from streamlit==1.4.0->-r requirements.txt (line 5)) (0.8.1)
# Requirement already satisfied: pandas>=0.21.0 in /usr/local/lib/python3.7/dist-packages (from streamlit==1.4.0->-r requirements.txt (line 5)) (1.1.5)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from streamlit==1.4.0->-r requirements.txt (line 5)) (3.10.0.2)
# Requirement already satisfied: pympler>=0.9 in /usr/local/lib/python3.7/dist-packages (from streamlit==1.4.0->-r requirements.txt (line 5)) (1.0.1)
# Requirement already satisfied: attrs in /usr/local/lib/python3.7/dist-packages (from streamlit==1.4.0->-r requirements.txt (line 5)) (21.4.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from streamlit==1.4.0->-r requirements.txt (line 5)) (2.8.2)
# Collecting sacremoses
#   Downloading sacremoses-0.0.47-py2.py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 57.8 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.15.0->-r requirements.txt (line 6)) (2019.12.20)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 54.6 MB/s
# Collecting tokenizers>=0.10.3
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 60.7 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers==4.15.0->-r requirements.txt (line 6)) (4.10.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==4.15.0->-r requirements.txt (line 6)) (3.4.2)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.7/dist-packages (from altair>=3.2.0->streamlit==1.4.0->-r requirements.txt (line 5)) (4.3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from altair>=3.2.0->streamlit==1.4.0->-r requirements.txt (line 5)) (2.11.3)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.7/dist-packages (from altair>=3.2.0->streamlit==1.4.0->-r requirements.txt (line 5)) (0.3)
# Requirement already satisfied: toolz in /usr/local/lib/python3.7/dist-packages (from altair>=3.2.0->streamlit==1.4.0->-r requirements.txt (line 5)) (0.11.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.7/dist-packages (from gitpython!=3.1.19->streamlit==1.4.0->-r requirements.txt (line 5)) (4.0.9)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.7/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19->streamlit==1.4.0->-r requirements.txt (line 5)) (5.0.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit==1.4.0->-r requirements.txt (line 5)) (0.18.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit==1.4.0->-r requirements.txt (line 5)) (5.4.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from importlib-resources>=1.4.0->jsonschema>=3.0->altair>=3.2.0->streamlit==1.4.0->-r requirements.txt (line 5)) (3.7.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->streamlit==1.4.0->-r requirements.txt (line 5)) (3.0.6)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.21.0->streamlit==1.4.0->-r requirements.txt (line 5)) (2018.9)
# Requirement already satisfied: ipywidgets>=7.0.0 in /usr/local/lib/python3.7/dist-packages (from pydeck>=0.1.dev5->streamlit==1.4.0->-r requirements.txt (line 5)) (7.6.5)
# Requirement already satisfied: traitlets>=4.3.2 in /usr/local/lib/python3.7/dist-packages (from pydeck>=0.1.dev5->streamlit==1.4.0->-r requirements.txt (line 5)) (5.1.1)
# Requirement already satisfied: ipykernel>=5.1.2 in /usr/local/lib/python3.7/dist-packages (from pydeck>=0.1.dev5->streamlit==1.4.0->-r requirements.txt (line 5)) (6.7.0)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==1.4.0->-r requirements.txt (line 5)) (0.1.3)
# Requirement already satisfied: jupyter-client<8.0 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==1.4.0->-r requirements.txt (line 5)) (5.3.5)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==1.4.0->-r requirements.txt (line 5)) (1.0.0)
# Requirement already satisfied: ipython>=7.23.1 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==1.4.0->-r requirements.txt (line 5)) (7.31.0)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.7/dist-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==1.4.0->-r requirements.txt (line 5)) (1.5.4)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==1.4.0->-r requirements.txt (line 5)) (3.0.24)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.7/dist-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==1.4.0->-r requirements.txt (line 5)) (4.8.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==1.4.0->-r requirements.txt (line 5)) (4.4.2)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.7/dist-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==1.4.0->-r requirements.txt (line 5)) (0.18.1)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==1.4.0->-r requirements.txt (line 5)) (2.6.1)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==1.4.0->-r requirements.txt (line 5)) (0.7.5)
# Requirement already satisfied: backcall in /usr/local/lib/python3.7/dist-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==1.4.0->-r requirements.txt (line 5)) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==1.4.0->-r requirements.txt (line 5)) (57.4.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.4.0->-r requirements.txt (line 5)) (1.0.2)
# Requirement already satisfied: nbformat>=4.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.4.0->-r requirements.txt (line 5)) (5.1.3)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.4.0->-r requirements.txt (line 5)) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.4.0->-r requirements.txt (line 5)) (3.5.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==1.4.0->-r requirements.txt (line 5)) (0.8.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->altair>=3.2.0->streamlit==1.4.0->-r requirements.txt (line 5)) (2.0.1)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.7/dist-packages (from jupyter-client<8.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==1.4.0->-r requirements.txt (line 5)) (22.3.0)
# Requirement already satisfied: jupyter-core>=4.6.0 in /usr/local/lib/python3.7/dist-packages (from jupyter-client<8.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==1.4.0->-r requirements.txt (line 5)) (4.9.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==1.4.0->-r requirements.txt (line 5)) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==1.4.0->-r requirements.txt (line 5)) (0.2.5)
# Collecting colorama<0.5.0,>=0.4.0
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Collecting commonmark<0.10.0,>=0.9.0
#   Downloading commonmark-0.9.1-py2.py3-none-any.whl (51 kB)
#      |████████████████████████████████| 51 kB 5.9 MB/s
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.22.2->keybert==0.5.0->-r requirements.txt (line 1)) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.22.2->keybert==0.5.0->-r requirements.txt (line 1)) (3.0.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.7/dist-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.4.0->-r requirements.txt (line 5)) (5.3.1)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.4.0->-r requirements.txt (line 5)) (5.6.1)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.4.0->-r requirements.txt (line 5)) (0.12.1)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.4.0->-r requirements.txt (line 5)) (1.8.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.4.0->-r requirements.txt (line 5)) (0.7.1)
# Requirement already satisfied: testpath in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.4.0->-r requirements.txt (line 5)) (0.5.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.4.0->-r requirements.txt (line 5)) (4.1.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.4.0->-r requirements.txt (line 5)) (1.5.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.4.0->-r requirements.txt (line 5)) (0.8.4)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.4.0->-r requirements.txt (line 5)) (0.5.1)
# Building wheels for collected packages: keybert, sentence-transformers
#   Building wheel for keybert (setup.py) ... done
#   Created wheel for keybert: filename=keybert-0.5.0-py3-none-any.whl size=20491 sha256=bbbe919859e4f837e5a7835c8a542338b3e6f971dafd986f1c9f9ad61e037a2d
#   Stored in directory: /root/.cache/pip/wheels/99/1f/3f/590d2997adbb2d0e1f82e8ee05d42d6910e92c3ed283015ff8
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.1.0-py3-none-any.whl size=120999 sha256=14af190582679f1822dd590c7d257c6af06fa2edc105fd36483ff93b94018141
#   Stored in directory: /root/.cache/pip/wheels/90/f0/bb/ed1add84da70092ea526466eadc2bfb197c4bcb8d4fa5f7bad
# Successfully built keybert sentence-transformers
# Installing collected packages: pyyaml, tokenizers, sacremoses, huggingface-hub, transformers, sentencepiece, commonmark, colorama, sentence-transformers, rich, keybert
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed colorama-0.4.4 commonmark-0.9.1 huggingface-hub-0.4.0 keybert-0.5.0 pyyaml-6.0 rich-11.0.0 sacremoses-0.0.47 sentence-transformers-2.1.0 sentencepiece-0.1.96 tokenizers-0.10.3 transformers-4.15.0

# %% [markdown]
# ## Run App

# %%
# !streamlit run app.py --server.enableCORS=false &>/dev/null&

# !lt --Bypass-Tunnel-Reminder --subdomain 'myapp' --port 8501 &>/dev/null&

# %%
# kill app and clean up memory
st_id = !pgrep streamlit
# !kill {st_id[0]}

lt_id = !pgrep lt
# !kill {lt_id[0]}

# %% [markdown]
# ## Setup CI/CD Pipeline

# %% [markdown]
# Now, for production deployment, we would first setup a CI/CD pipeline.
#
# 1. first we, dockerize our app and push the code to container registry (Google's GCR) using Dockerfile and docker build.
#
# 2. Automate deployment using Cloud Build such that everytime we push our code to Github our app gets deployed with latest changes.

# %%
# %%writefile Dockerfile
# #Base Image to use
# FROM python:3.7.9-slim
#
# #Expose port 8080
# EXPOSE 8080
#
# #Optional - install git to fetch packages directly from github
# RUN apt-get update && apt-get install -y git
#
# #Copy Requirements.txt file into app directory
# COPY requirements.txt app/requirements.txt
# COPY env app/.env
#
# #install all requirements in requirements.txt
# RUN pip install -r app/requirements.txt
#
# #Copy all files in current directory into app directory
# COPY . /app
#
# #Change Working Directory to app directory
# WORKDIR /app
#
# #Run the application on port 8080
# ENTRYPOINT ["streamlit", "run", "app.py", "--server.port=8080", "--server.address=0.0.0.0"]
# Out:
# Writing Dockerfile

# %%
# %%writefile cloudbuild.yaml
#
# steps:
# - name: 'gcr.io/cloud-builders/docker'
#   args: [ 'build', '-t', 'gcr.io/mcq-from-text/mcq-app:latest', '.' ]
# images: [gcr.io/mcq-from-text/mcq-app:latest]
# Out:
# Writing cloudbuild.yaml

# %%
from google.colab import auth
auth.authenticate_user()

# setup Google Cloud project

PROJECT_ID = 'mcq-from-text'
# !gcloud config set project {PROJECT_ID}
# Out:
# Updated property [core/project].

# %%
# now, we package our code as docker image using Dockerfile and push it to Google's Container Registry

# 1. build image locally and test run at localhost
# !docker build  --timeout 20m --tag gcr.io/{PROJECT_ID}/mcq-app:latest .

# 2. build using gcloud
# !docker build  --timeout 20m --tag gcr.io/{PROJECT_ID}/mcq-app:latest .

# 3. submit to Google's Container registry
# !gcloud builds submit --timeout 30m  --tag gcr.io/${PROJECT_ID}/mcq-app:latest
